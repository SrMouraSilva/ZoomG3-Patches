# %% [markdown]
# # Tratamento de dados 2
#
# A partir de uma lista de pedalboards (`data/pedalboards-info.csv`), tentaremos obter os pedalboards.

# %% [markdown]
# ## Lista de pedalboards

# %%
import pandas as pd
pedalboards = pd.read_csv('data/pedalboard-info.csv', index_col='index').sort_index()

pedalboards.head()
# Out:
#                                         link               title  \
# index
# 5299   patches.php?mode=show&unit=G3&ID=5299         plexi-delay
# 5300   patches.php?mode=show&unit=G3&ID=5300     Tom Scholz tone
# 5301   patches.php?mode=show&unit=G3&ID=5301          Very Clean
# 5302   patches.php?mode=show&unit=G3&ID=5302  Pitch Rising Delay
# 5303   patches.php?mode=show&unit=G3&ID=5303               2Tone
#
#                 artist  rating has_audio has_video        date      uploader  \
# index
# 5299              many     4.3     False     False  2011-08-18         otter
# 5300   Boston - Smokin     3.5     False     False  2011-08-20  Henky Backer
# 5301               n/a     3.0     False     False  2011-08-22         Jimis
# 5302           Battles     1.0     False     False  2011-08-22         Jimis
# 5303             2Tone     1.0     False     False  2011-08-22         Jimis
#
#        total_downloads
# index
# 5299              2899
# 5300              4744
# 5301              2293
# 5302              1310
# 5303              1568

# %% [markdown]
# ## Total de pedalboards na lista

# %%
len(pedalboards)
# Out:
# 862

# %% [markdown]
# ## Função para obter pedalboards
#
# É esperado que o pedalboard tenha o formato **XML**.
#
# Testaremos com o primeiro pedalboard da lista:

# %%
import requests
import xmltodict
import cgi

def read_pedalboard(index):
    response = requests.get('http://guitarpatches.com/download.php?unit=G3&mode=download&ID={}'.format(index))
    
    value, params = cgi.parse_header(response.headers['Content-Disposition'])
    filename = params['filename']
    
    try:
        data = xmltodict.parse(response.content)
    except:
        data = response.content
    
    return {
        'index': index,
        'filename': filename,
        'data': data
    }

# %%
pedalboard_g3v1 = read_pedalboard(pedalboards.index[0])
pedalboard_g3v2 = read_pedalboard(pedalboards.index[-1])

#pedalboard_g3v1
#pedalboard_g3v2

# %% [markdown]
# ## Extrair informações importantes do modelo de dados
#
# Inicialmente queremos somente o nome do pedalboard e o índice dos plugins de áudio utilizados neste pedalboard

# %%
def extract_data(pedalboard):
    index = pedalboard['index']
    extension = pedalboard['filename'].split('.')[-1]
    
    if extension == 'g3p':
        return extract_data_g3pn(index, pedalboard['data']['PatchData'], 3)
    elif extension == 'g3a':
        return extract_data_g3an(index, pedalboard['data'], 3)
    elif extension == 'g3xp':
        return extract_data_g3pn(index, pedalboard['data']['PatchData'], 6)
    elif extension == 'g3xa':
        return extract_data_g3an(index, pedalboard['data'], 6)
    elif extension == 'zip':
        return extract_data_zip(index, pedalboard['data'])
    else:
        raise Exception('Unknown format: {}'.format(extension))

def extract_data_g3pn(index, pedalboard, total):
    """
    Extract data for a pedalboard with a total audio plugins elements
    """
    data = [index, pedalboard['Name']]

    for index in range(0, total):
        data.append(pedalboard['Module{}'.format(index)]['Prm1'])
    
    return [data]

def extract_data_g3an(index, pedalboards, total):
    """
    Extract data for a pedalboard with a total audio plugins elements
    """
    function = lambda pedalboard: extract_data_g3pn(index, pedalboard, total)[0]
    return list(map(function, pedalboards['PatchSet']['Patches']['PatchData']))

import zipfile
import io

def extract_data_zip(index, data):
    zipped = zipfile.ZipFile(io.BytesIO(data))
    result = []
    
    for name in zipped.namelist():
        result += extract_data({
            'index': index,
            'data': xmltodict.parse(zipped.read(name)),
            'filename': name
        })
    
    return result

extract_data(pedalboard_g3v1) + extract_data(pedalboard_g3v2)
# Out:
# [[5299, 'plexi*dly*', '74', '102', '55'],
#  [10872, 'Bass******', '30', '37', '94', '24', '107', '107']]

# %% [markdown]
# ## Processar toda a lista de plugins
#
# Processamentos todos os pedalboards listados. Serão geradas duas listas
#
#  * `data`: Plugins processados
#  * `errors`: [index, Causa do erro]
#
# Erros podem ocorrer por:
#  * Arquivos compactados.

# %%
def process_mode_one():
    data = []
    errors = []

    for i, index in enumerate(pedalboards.index):
        print(i, index, end='')

        try:
            pedalboard = read_pedalboard(index)
            data += extract_data(pedalboard)
            print()
        except Exception as e:
            errors.append((index, e))
            print('', e)

    return data

# %%
import multiprocessing

try:
    cpus = multiprocessing.cpu_count()
except NotImplementedError:
    cpus = 2   # arbitrary default

cpus = 32

def process(index):
    i, index = index
    print(i, index)

    data = []
    error = None

    try:
        pedalboard = read_pedalboard(index)
        data = extract_data(pedalboard)
    except Exception as e:
        error = (index, e)
        print(index, '-', e)

    return data, error

pool = multiprocessing.Pool(processes=cpus)
result = pool.map(process, enumerate(pedalboards.index))

result
# Out:
# 0 5299
# 7 5347
# 35 5482
# 42 5703
# 70 5939
# 77 6075
# 56 5763
# 119 6452
# 112 6361
# 14 5360
# 84 6209
# 91 6261
# 21 5381
# 98 6280
# 133 6498
# 126 6461
# 105 6293
# 168 6730
# 210 6960
# 175 6745
# 161 6694
# 182 6776
# 154 6591
# 196 6879
# 63 5875
# 203 6934
# 217 6986
# 189 6826
# 49 5740
# 28 5435
# 147 6581
# 140 6558
# 36 5485
# 1 5300
# 57 5765
# 92 6262
# 85 6210
# 190 6827
# 106 6341
# 78 6076
# 197 6903
# 99 6281
# 6361 - 'content-disposition'
# 113 6380
# 64 5877
# 148 6582
# 8 5350
# 43 5705
# 15 5361
# 155 6592
# 120 6453
# 211 6961
# 29 5438
# 127 6462
# 134 6499
# 22 5398
# 218 6987
# 71 5940
# 50 5743
# 58 5768
# 204 6935
# 191 6833
# 176 6752
# 93 6275
# 2 5301
# 86 6230
# 37 5487
# 169 6734
# 114 6381
# 162 6696
# 100 6287
# 107 6342
# 79 6150
# 141 6573
# 65 5878
# 149 6584
# 183 6787
# 198 6929
# 44 5730
# 9 5352
# 16 5367
# 121 6454
# 30 5453
# 128 6490
# 212 6971
# 156 6610
# 135 6500
# 23 5401
# 72 5991
# 51 5751
# 59 5815
# 219 6988
# 94 6276
# 205 6955
# 3 5302
# 38 5655
# 170 6738
# 108 6344
# 142 6575
# 115 6389
# 87 6232
# 101 6288
# 177 6763
# 163 6702
# 192 6835
# 80 6168
# 66 5891
# 150 6585
# 184 6788
# 199 6930
# 10 5355
# 17 5368
# 45 5731
# 31 5475
# 122 6455
# 213 6972
# 129 6491
# 206 6956
# 136 6501
# 24 5402
# 60 5832
# 73 6026
# 95 6277
# 39 5671
# 171 6740
# 4 5303
# 109 6345
# 116 6413
# 52 5756
# 102 6289
# 88 6233
# 143 6576
# 220 6993
# 178 6764
# 157 6634
# 164 6710
# 81 6170
# 193 6842
# 67 5892
# 151 6586
# 185 6806
# 200 6931
# 11 5357
# 18 5371
# 46 5732
# 32 5476
# 123 6458
# 207 6957
# 137 6555
# 130 6492
# 214 6974
# 61 5849
# 74 6070
# 96 6278
# 40 5695
# 25 5424
# 5 5304
# 172 6742
# 158 6679
# 53 5757
# 117 6440
# 221 7000
# 179 6765
# 110 6350
# 103 6291
# 165 6717
# 89 6234
# 144 6577
# 82 6176
# 194 6846
# 68 5893
# 152 6587
# 186 6819
# 201 6932
# 47 5734
# 12 5358
# 33 5478
# 124 6459
# 208 6958
# 131 6493
# 138 6556
# 215 6984
# 97 6279
# 41 5696
# 26 5429
# 75 6071
# 173 6743
# 62 5853
# 166 6718
# 6 5307
# 54 5760
# 180 6766
# 159 6680
# 111 6352
# 83 6177
# 195 6847
# 145 6578
# 118 6451
# 104 6292
# 69 5938
# 222 7001
# 90 6259
# 153 6588
# 187 6824
# 202 6933
# 19 5372
# 48 5735
# 13 5359
# 34 5481
# 139 6557
# 209 6959
# 125 6460
# 132 6497
# 216 6985
# 76 6072
# 27 5431
# 224 7005
# 231 7035
# 238 7082
# 167 6719
# 181 6767
# 160 6685
# 174 6744
# 245 7126
# 55 5762
# 252 7171
# 266 7227
# 259 7208
# 146 6579
# 273 7265
# 280 7276
# 223 7002
# 294 7316
# 287 7288
# 188 6825
# 301 7397
# 308 7495
# 20 5375
# 315 7532
# 322 7547
# 329 7577
# 336 7602
# 343 7645
# 350 7672
# 357 7695
# 364 7752
# 225 7007
# 371 7765
# 378 7782
# 232 7042
# 392 7867
# 253 7181
# 385 7843
# 246 7144
# 260 7210
# 399 7883
# 274 7266
# 281 7277
# 406 7908
# 413 7942
# 288 7296
# 427 7973
# 420 7960
# 267 7231
# 434 8098
# 302 7445
# 239 7083
# 295 7322
# 309 7515
# 441 8143
# 316 7533
# 330 7583
# 337 7603
# 351 7673
# 365 7753
# 358 7698
# 372 7769
# 226 7008
# 379 7783
# 261 7216
# 233 7050
# 386 7846
# 393 7870
# 247 7145
# 400 7884
# 254 7188
# 275 7271
# 282 7279
# 289 7310
# 414 7943
# 428 7975
# 268 7233
# 421 7961
# 407 7910
# 435 8099
# 303 7461
# 296 7341
# 310 7516
# 240 7098
# 323 7555
# 317 7536
# 442 8145
# 331 7585
# 338 7604
# 366 7760
# 373 7771
# 352 7674
# 359 7699
# 227 7009
# 380 7784
# 234 7051
# 262 7217
# 394 7877
# 248 7159
# 415 7946
# 290 7312
# 387 7855
# 7975 - Unknown format: jpg
# 276 7272
# 429 7976
# 401 7887
# 422 7962
# 344 7646
# 255 7199
# 283 7281
# 269 7241
# 408 7927
# 436 8100
# 304 7463
# 297 7343
# 311 7523
# 241 7105
# 324 7558
# 318 7540
# 443 8156
# 332 7598
# 339 7628
# 367 7761
# 374 7773
# 353 7675
# 228 7021
# 235 7061
# 360 7700
# 395 7878
# 381 7817
# 263 7218
# 249 7163
# 277 7273
# 416 7948
# 7976 - Unknown format: jpg
# 402 7898
# 430 7986
# 409 7928
# 284 7283
# 270 7254
# 437 8101
# 256 7200
# 305 7464
# 298 7386
# 312 7527
# 242 7116
# 291 7313
# 388 7856
# 423 7963
# 325 7559
# 319 7542
# 444 8173
# 333 7599
# 340 7629
# 345 7647
# 368 7762
# 354 7680
# 229 7025
# 236 7062
# 361 7701
# 396 7879
# 382 7824
# 250 7166
# 264 7220
# 417 7952
# 278 7274
# 403 7899
# 431 8090
# 285 7286
# 410 7937
# 438 8115
# 271 7257
# 257 7205
# 306 7465
# 299 7388
# 375 7774
# 313 7530
# 243 7117
# 389 7860
# 424 7964
# 326 7561
# 320 7544
# 445 8174
# 334 7600
# 292 7314
# 341 7638
# 369 7763
# 355 7693
# 237 7074
# 230 7029
# 362 7702
# 397 7880
# 251 7168
# 265 7226
# 383 7839
# 418 7954
# 279 7275
# 404 7905
# 432 8091
# 439 8139
# 286 7287
# 258 7206
# 272 7264
# 411 7938
# 300 7391
# 307 7478
# 376 7780
# 314 7531
# 244 7124
# 390 7865
# 425 7965
# 327 7567
# 321 7545
# 446 8181
# 346 7662
# 335 7601
# 342 7642
# 293 7315
# 356 7694
# 370 7764
# 448 8194
# 7074 - Unknown format: rar
# 455 8228
# 363 7747
# 398 7881
# 462 8256
# 384 7842
# 405 7906
# 469 8285
# 433 8092
# 476 8296
# 419 7959
# 440 8142
# 483 8323
# 490 8340
# 412 7939
# 497 8347
# 504 8378
# 377 7781
# 511 8440
# 518 8513
# 391 7866
# 426 7968
# 328 7568
# 525 8529
# 447 8183
# 532 8536
# 347 7663
# 539 8550
# 546 8574
# 553 8666
# 449 8196
# 456 8234
# 560 8725
# 463 8257
# 567 8748
# 574 8775
# 581 8801
# 588 8819
# 602 8917
# 470 8286
# 595 8890
# 477 8299
# 484 8334
# 491 8341
# 616 9074
# 609 8975
# 623 9134
# 498 8348
# 630 9262
# 505 8393
# 512 8447
# 519 8514
# 637 9285
# 644 9304
# 651 9329
# 526 8530
# 533 8540
# 348 7664
# 540 8555
# 450 8198
# 554 8687
# 457 8236
# 547 8581
# 561 8727
# 464 8259
# 575 8776
# 568 8750
# 589 8825
# 603 8918
# 582 8802
# 471 8287
# 478 8300
# 596 8891
# 492 8342
# 485 8335
# 617 9090
# 610 8976
# 624 9135
# 499 8356
# 631 9265
# 506 8405
# 8447 - Unknown format: g5p
# 513 8461
# 520 8524
# 658 9362
# 645 9307
# 652 9334
# 527 8531
# 534 8542
# 541 8558
# 349 7665
# 451 8207
# 555 8690
# 458 8246
# 548 8616
# 562 8730
# 465 8273
# 576 8781
# 569 8751
# 590 8827
# 604 8928
# 583 8803
# 472 8288
# 479 8303
# 597 8897
# 486 8336
# 493 8343
# 618 9091
# 500 8362
# 625 9142
# 611 8977
# 632 9268
# 507 8415
# 514 8494
# 521 8525
# 659 9363
# 638 9286
# 646 9309
# 653 9345
# 528 8532
# 535 8543
# 542 8559
# 665 9379
# 556 8696
# 452 8215
# 549 8620
# 459 8247
# 563 8735
# 466 8274
# 577 8782
# 591 8838
# 605 8964
# 570 8752
# 584 8804
# 473 8289
# 480 8312
# 487 8337
# 494 8344
# 619 9092
# 626 9143
# 633 9269
# 612 8978
# 508 8417
# 501 8363
# 515 8510
# 522 8526
# 660 9368
# 647 9310
# 639 9289
# 654 9346
# 529 8533
# 536 8544
# 666 9387
# 543 8560
# 557 8715
# 453 8223
# 564 8736
# 460 8248
# 550 8638
# 467 8275
# 598 8913
# 578 8784
# 592 8844
# 606 8966
# 571 8753
# 474 8290
# 585 8807
# 481 8313
# 495 8345
# 488 8338
# 620 9093
# 627 9145
# 634 9271
# 509 8435
# 613 9040
# 502 8364
# 516 8511
# 648 9311
# 523 8527
# 640 9297
# 661 9369
# 655 9347
# 530 8534
# 537 8545
# 667 9389
# 544 8562
# 565 8738
# 461 8255
# 454 8225
# 468 8284
# 579 8786
# 593 8853
# 607 8973
# 572 8756
# 475 8292
# 8313 - Unknown format: rar
# 482 8322
# 586 8808
# 496 8346
# 489 8339
# 621 9105
# 628 9194
# 517 8512
# 635 9272
# 614 9043
# 510 8438
# 503 8365
# 649 9318
# 662 9375
# 524 8528
# 641 9298
# 656 9348
# 599 8914
# 531 8535
# 538 8546
# 558 8723
# 668 9392
# 545 8573
# 551 8660
# 672 9404
# 679 9431
# 566 8745
# 686 9467
# 594 8855
# 608 8974
# 573 8774
# 693 9504
# 700 9543
# 580 8791
# 587 8814
# 707 9573
# 714 9594
# 622 9133
# 629 9239
# 721 9605
# 636 9273
# 615 9066
# 650 9327
# 728 9622
# 735 9685
# 742 9742
# 663 9376
# 642 9302
# 657 9349
# 749 9773
# 600 8915
# 756 9792
# 559 8724
# 763 9822
# 669 9400
# 552 8663
# 680 9432
# 673 9415
# 770 9864
# 777 9871
# 784 9902
# 791 10137
# 694 9523
# 798 10207
# 701 9550
# 708 9574
# 805 10224
# 715 9595
# 812 10237
# 819 10346
# 826 10490
# 722 9613
# 833 10518
# 736 9686
# 840 10622
# 743 9743
# 664 9377
# 643 9303
# 847 10678
# 750 9774
# 601 8916
# 757 9806
# 854 10778
# 764 9825
# 670 9401
# 861 10872
# 674 9416
# 681 9444
# 687 9471
# 778 9876
# 771 9865
# 785 9907
# 695 9524
# 792 10146
# 799 10210
# 729 9627
# 702 9568
# 709 9575
# 813 10245
# 716 9596
# 820 10350
# 827 10491
# 723 9614
# 834 10520
# 841 10623
# 744 9752
# 737 9687
# 10678 - Unknown format: zptc
# 848 10693
# 751 9775
# 758 9809
# 10778 - Unknown format: zptc
# 855 10779
# 765 9831
# 671 9403
# 682 9446
# 772 9866
# 786 9913
# 806 10229
# 696 9529
# 793 10148
# 800 10211
# 730 9630
# 703 9569
# 710 9588
# 814 10252
# 717 9597
# 821 10403
# 828 10492
# 724 9615
# 9876 - Unknown format: rar
# 779 9884
# 835 10532
# 745 9768
# 849 10720
# 738 9688
# 688 9472
# 752 9776
# 759 9810
# 10779 - Unknown format: zptc
# 856 10822
# 766 9833
# 683 9447
# 773 9867
# 787 9920
# 697 9530
# 807 10231
# 794 10190
# 731 9635
# 801 10214
# 718 9598
# 815 10323
# 829 10508
# 725 9616
# 850 10774
# 780 9897
# 836 10536
# 746 9769
# 739 9690
# 842 10629
# 753 9779
# 760 9812
# 767 9838
# 684 9452
# 704 9570
# 774 9868
# 9416 - Unknown format: g5a
# 675 9417
# 788 9923
# 808 10232
# 698 9540
# 711 9589
# 10190 - Unknown format: xml
# 795 10197
# 732 9637
# 802 10215
# 719 9599
# 830 10509
# 816 10324
# 10774 - Unknown format: zptc
# 747 9771
# 726 9617
# 851 10775
# 837 10567
# 689 9477
# 781 9899
# 843 10630
# 740 9739
# 754 9790
# 822 10418
# 761 9816
# 857 10849
# 768 9843
# 705 9571
# 685 9455
# 775 9869
# 699 9542
# 789 9924
# 809 10233
# 712 9592
# 733 9638
# 796 10200
# 803 10219
# 720 9604
# 817 10325
# 831 10510
# 748 9772
# 10775 - Unknown format: zptc
# 852 10776
# 727 9618
# 782 9900
# 838 10568
# 690 9488
# 844 10640
# 741 9740
# 823 10419
# 755 9791
# 762 9817
# 676 9419
# 706 9572
# 790 9925
# 776 9870
# 9592 - no element found: line 1, column 0
# 810 10234
# 734 9672
# 713 9593
# 797 10201
# 804 10220
# 832 10517
# 858 10850
# 818 10327
# 10776 - Unknown format: zptc
# 853 10777
# 691 9490
# 839 10580
# 769 9844
# 783 9901
# 824 10428
# 677 9422
# 10640 - 'Module5'
# 845 10661
# 811 10235
# 10777 - Unknown format: zptc
# 692 9497
# 825 10430
# 678 9423
# 846 10667
# 859 10870
# 860 10871
# [([[5299, 'plexi*dly*', '74', '102', '55']], None),
#  ([[5300, 'HB*Boston3', '31', '102', '33']], None),
#  ([[5301, '_Clean****', '24', '31', '28']], None),
#  ([[5302, '_Battles**', '72', '107', '7']], None),
#  ([[5303, '_2tone****', '72', '57', '96']], None),
#  ([[5304, 'Numb______', '81', '57', '100']], None),
#  ([[5307, '_Ethereal', '31', '109', '59']], None),
#  ([[5347, 'The*Solo**', '105', '28', '19']], None),
#  ([[5350, 'AC*DC*****', '28', '103', '61']], None),
#  ([[5352, 'M1*Thom***', '8', '104', '28']], None),
#  ([[5355, 'Slash*****', '24', '72', '102']], None),
#  ([[5357, 'ACDC******', '55', '102', '61']], None),
#  ([[5358, 'DearPruden', '96', '42', '55']], None),
#  ([[5359, 'PaganBaby*', '100', '64', '67']], None),
#  ([[5360, 'WalkOnWate', '96', '64', '67']], None),
#  ([[5361, 'RambleTamb', '100', '64', '67']], None),
#  ([[5367, 'Clean', '24', '19', '31']], None),
#  ([[5368, 'solo*4*b*', '31', '78', '17']], None),
#  ([[5371, 'Blues*****', '31', '98', '62']], None),
#  ([[5372, 'Money4Noth', '28', '103', '65']], None),
#  ([[5375, 'Blvd*of*BD', '108', '77', '39']], None),
#  ([[5381, 'Lightning*', '72', '40', '96']], None),
#  ([[5398, 'WickedGame', '96', '64', '57']], None),
#  ([[5401, 'JoanJett**', '29', '103', '61']], None),
#  ([[5402, 'Get*Back**', '97', '64', '67']], None),
#  ([[5424, 'AC-Solo', '86', '31', '67']], None),
#  ([[5429, 'Djent*****', '81', '31', '45']], None),
#  ([[5431, 'Shredding', '73', '103', '66']], None),
#  ([[5435, 'REM*******', '56', '17', '19']], None),
#  ([[5438, 'Rocking', '73', '106', '28']], None),
#  ([[5453, 'barracuda*', '101', '61', '48']], None),
#  ([[5475, 'Djent*****', '28', '85', '31']], None),
#  ([[5476, 'Petrucci**', '104', '72', '31']], None),
#  ([[5478, '11Th*HOUR*', '104', '28', '17']], None),
#  ([[5481, 'HB*eVh****', '47', '103', '57']], None),
#  ([[5482, 'DZ*DRIVE**', '105', '28', '62']], None),
#  ([[5485, 'TeleLead**', '24', '108', '31']], None),
#  ([[5487, 'JIMI*FUZZ*', '79', '2', '65']], None),
#  ([[5655, 'Slash*****', '31', '103', '19']], None),
#  ([[5671, 'HBChevelle', '28', '104', '32']], None),
#  ([[5695, 'Wylde*****', '73', '103', '42']], None),
#  ([[5696, 'Foo*Fight*', '72', '100', '24']], None),
#  ([[5703, 'Bush******', '79', '108', '24']], None),
#  ([[5705, 'Clapton***', '74', '108', '28']], None),
#  ([[5730, 'LonnieMack', '2', '103', '42']], None),
#  ([[5731, 'RGallagher', '97', '72', '29']], None),
#  ([[5732, 'RGallagh*2', '96', '25', '28']], None),
#  ([[5734, 'TheShadows', '8', '31', '24']], None),
#  ([[5735, 'TheShadow2', '55', '55', '67']], None),
#  ([[5740, '_fuzzy****', '29', '80', '46']], None),
#  ([[5743, 'Metallica*', '73', '99', '32']], None),
#  ([[5751, 'Via-FTLOG*', '44', '104', '19']], None),
#  ([[5756, 'ComBkLifeI', '96', '54', '19']], None),
#  ([[5757, 'ComBkLfe2a', '100', '33', '8']], None),
#  ([[5760, 'Sidewalk**', '97', '8', '66']], None),
#  ([[5762, 'TOTO-HTL', '74', '107', '45']], None),
#  ([[5763, 'Cowboys***', '110', '105', '31']], None),
#  ([[5765, 'LaGngClean', '86', '31', '109']], None),
#  ([[5768, 'LaGrngHumB', '105', '31', '8']], None),
#  ([[5815, 'OldSmith**', '24', '102', '24']], None),
#  ([[5832, 'Twin*Set**', '26', '96', '65']], None),
#  ([[5849, 'SLaYeR****', '29', '73', '103']], None),
#  ([[5853, 'StHillage*', '83', '6', '43']], None),
#  ([[5875, 'GILMOUR***', '100', '45', '57']], None),
#  ([[5877, 'Gary*Moore', '104', '61', '28']], None),
#  ([[5878, 'Healing***', '86', '19', '109']], None),
#  ([[5891, 'ZKUN*Drive', '28', '104', '61']], None),
#  ([[5892, 'LowMansLyr', '96', '46', '61']], None),
#  ([[5893, 'Fuel******', '28', '73', '103']], None),
#  ([[5938, 'Smells****', '28', '104', '67']], None),
#  ([[5939, 'Cowboys***', '28', '105', '65']], None),
#  ([[5940, 'master*of*', '105', '19', '28']], None),
#  ([[5991, 'DIME*LIKE*', '30', '104', '32']], None),
#  ([[6026, 'PERSIANA**', '96', '8', '17']], None),
#  ([[6070, 'AH*Clean**', '86', '92', '55', '7', '7', '7']], None),
#  ([[6071, 'AH*lead1**', '71', '95', '27', '31', '7', '7']], None),
#  ([[6072, 'AH*lead2**', '71', '30', '114', '27', '7', '7']], None),
#  ([[6075, 'SLO*SHIM**', '52', '26', '5', '6', '55', '18']], None),
#  ([[6076, 'LEAD*SHIM*', '89', '26', '52', '5', '55', '18']], None),
#  ([[6150, 'SweetChild', '30', '74', '97', '27', '63', '105']], None),
#  ([[6168, 'SURVIVOR', '82', '28', '8']], None),
#  ([[6170, '0LA*Beybe*', '24', '73', '71', '30', '27', '113']], None),
#  ([[6176, 'HBRecharge', '27', '73', '97', '42', '64', '107']], None),
#  ([[6177, 'TeenSpirit', '77', '95', '45', '27', '62', '66']], None),
#  ([[6209, 'Petrucci', '27', '39', '72', '95', '30', '62']], None),
#  ([[6210, 'JP-Clean', '23', '85', '41', '30', '54', '60']], None),
#  ([[6230, 'TimeHsCome', '24', '73', '71', '103', '53', '60']], None),
#  ([[6232, 'Hossana***', '23', '73', '93', '55', '56', '60']], None),
#  ([[6233, 'Strings***', '93', '26', '6', '55', '18', '107']], None),
#  ([[6234, 'POP*PUNK**', '23', '76', '99', '49', '27', '61']], None),
#  ([[6259, 'Randy*****', '27', '72', '41', '99', '61', '107']], None),
#  ([[6261, 'Rock******', '43', '100', '27', '107', '107', '107']], None),
#  ([[6262, 'Clean*****', '85', '7', '60', '33', '41', '107']], None),
#  ([[6275, 'U2*where4*', '86', '24', '43', '93', '55', '56']], None),
#  ([[6276, 'U2*still2*', '24', '86', '93', '43', '55', '56']], None),
#  ([[6277, 'U2*pride**', '86', '24', '43', '93', '56', '58']], None),
#  ([[6278, 'U2*with4**', '86', '24', '93', '55', '56', '105']], None),
#  ([[6279, 'U2*In*God*', '86', '24', '93', '55', '56', '105']], None),
#  ([[6280, 'U2*Bad****', '86', '24', '93', '55', '58', '105']], None),
#  ([[6281, 'U2*Myst***', '19', '33', '81', '27', '93', '55']], None),
#  ([[6287, 'PF*Shine4*', '24', '21', '86', '96', '54', '105']], None),
#  ([[6288, 'PF*Shine3*', '19', '24', '86', '96', '54', '105']], None),
#  ([[6289, 'PF*Anothe2', '86', '24', '46', '92', '54', '105']], None),
#  ([[6291, 'PF*Echoes*', '24', '86', '81', '96', '54', '105']], None),
#  ([[6292, 'Samba*Pati', '86', '41', '24', '88', '109', '5']], None),
#  ([[6293, 'Europa****', '86', '41', '24', '88', '100', '5']], None),
#  ([[6341, 'Ambassador', '73', '53', '101', '39', '46', '27']], None),
#  ([[6342, 'Acoustic**', '60', '85', '23', '66', '31', '85']], None),
#  ([[6344, 'Slash*SCOM', '78', '98', '63', '27', '105', '23']], None),
#  ([[6345, 'Maiden****', '27', '107', '41', '115', '107', '61']], None),
#  ([[6350, 'Surf******', '64', '97', '54']], None),
#  ([[6352, 'CL-E.Br.U*', '23', '21', '36', '7', '64', '66']], None),
#  ([], (6361, KeyError('content-disposition'))),
#  ([[6380, 'Surf*3****', '23', '8', '92', '54', '38', '63']], None),
#  ([[6381, '*ENGL*BG**', '27', '112', '56', '105', '107', '77']], None),
#  ([[6389, 'Drive*****', '92', '25', '76', '79', '26', '37']], None),
#  ([[6413, 'POP*PUNK**', '23', '75', '97', '27', '55', '61']], None),
#  ([[6440, 'Gilmour***', '73', '79', '96', '1', '56', '107']], None),
#  ([[6451, 'Clean*****', '28', '24', '53', '105', '54', '107']], None),
#  ([[6452, 'Juan******', '28', '110', '37', '56', '105', '38']], None),
#  ([[6453, 'Creepy****', '28', '23', '8', '92', '53', '63']], None),
#  ([[6454, 'Clean*2***', '28', '25', '86', '41', '38', '107']], None),
#  ([[6455, 'Funk******', '28', '23', '86', '60', '107', '107']], None),
#  ([[6458, 'BrownSugar', '24', '94', '54', '63', '8', '66']], None),
#  ([[6459, '*ENGL*BG**', '27', '49', '112', '56', '105', '12']], None),
#  ([[6460, 'EVH.Old***', '27', '101', '30', '106', '53', '64']], None),
#  ([[6461, 'EVH1984***', '27', '101', '30', '106', '53', '64']], None),
#  ([[6462, 'NUNO******', '27', '100', '30', '106', '7', '64']], None),
#  ([[6490, 'Us*&*them*', '23', '86', '96', '44', '55', '105']], None),
#  ([[6491, 'Breath*2**', '19', '86', '92', '56', '18', '63']], None),
#  ([[6492, 'Try*******', '77', '71', '93', '8', '54', '18']], None),
#  ([[6493, 'Sweet2Disp', '24', '86', '8', '101', '7', '63']], None),
#  ([[6497, 'VX*CRUNCH*', '27', '23', '93', '107', '107', '107']], None),
#  ([[6498, 'VX*SOLO***', '27', '87', '93', '30', '56', '107']], None),
#  ([[6499, 'FEND*CRUNC', '27', '23', '92', '107', '107', '107']], None),
#  ([[6500, 'FEND*SOLO*', '27', '76', '92', '56', '107', '107']], None),
#  ([[6501, 'MS1959*BS*', '27', '72', '115', '107', '107', '107']], None),
#  ([[6555, 'Sex*Pistol', '27', '92', '107', '107', '107', '107']], None),
#  ([[6556, 'GrOb', '27', '77', '107', '107', '107', '107']], None),
#  ([[6557, 'Acustic***', '27', '85', '107', '107', '107', '107']], None),
#  ([[6558, 'Rithm*****', '27', '83', '107', '107', '107', '107']], None),
#  ([[6573, 'FaitNoMore', '28', '66', '64', '101', '107', '107']], None),
#  ([[6575, 'WhaleRocea', '40', '16', '24', '103', '18', '63']], None),
#  ([[6576, 'DelayRocea', '24', '40', '16', '103', '18', '63']], None),
#  ([[6577, 'Delay0ocea', '24', '2', '16', '103', '63', '64']], None),
#  ([[6578, 'BeatleHARD', '28', '93', '66', '60', '30', '107']], None),
#  ([[6579, 'OD*02*Hi**', '27', '72', '31', '30', '66', '60']], None),
#  ([[6581, 'OD*01*****', '27', '72', '31', '30', '66', '60']], None),
#  ([[6582, 'DS+*01****', '27', '75', '31', '30', '66', '1']], None),
#  ([[6584, 'BeatleSOFT', '28', '24', '93', '66', '30', '71']], None),
#  ([[6585, 'BOOWY*CLN*', '30', '24', '53', '44', '107', '105']], None),
#  ([[6586, 'BOOWY*OD2*', '73', '73', '24', '30', '107', '105']], None),
#  ([[6587, 'BOOWY*DIST', '77', '24', '30', '45', '66', '105']], None),
#  ([[6588, 'BOOWY*ER**', '77', '24', '105', '65', '65', '60']], None),
#  ([[6591, 'Gasoline', '28', '3', '39', '106', '38', '99']], None),
#  ([[6592, 'DS+*ZEP***', '68', '27', '75', '31', '30', '66']], None),
#  ([[6610, 'BOOWY*****', '23', '27', '75', '30', '44', '60']], None),
#  ([[6634, 'sntrium*c*', '21', '18', '28', '70', '107', '107']], None),
#  ([[6679, 'LaGngClean', '85', '71', '115', '30', '105', '107']], None),
#  ([[6680, 'LaGrngHumB', '102', '31', '65']], None),
#  ([[6685, 'Rithm*****', '27', '83', '107', '107', '107', '107']], None),
#  ([[6694, 'PinkSintro', '93', '24', '34', '26', '6', '18']], None),
#  ([[6696, 'gReNN*dayY', '35', '28', '100', '3', '65', '107']], None),
#  ([[6702, '*may*roam*', '111', '21', '18', '28', '68', '27']], None),
#  ([[6710, 'WAH*BGN***', '68', '84', '30', '29', '53', '64']], None),
#  ([[6717, 'Metal*test', '66', '106', '30', '24', '27', '113']], None),
#  ([[6718, 'Comf*Numb1', '79', '72', '30', '56', '96', '28']], None),
#  ([[6719, 'PF*Shine**', '23', '24', '72', '96', '54', '60']], None),
#  ([[6730, 'Metalcore*', '73', '72', '27', '98', '56', '71']], None),
#  ([[6734, 'Slash', '30', '74', '67', '99', '27', '61']], None),
#  ([[6738, 'Clean*Kirk', '23', '44', '56', '18', '107', '107']], None),
#  ([[6740, 'Joe*Sat', '27', '23', '112', '41', '55', '64']], None),
#  ([[6742, 'WAH*BGN***', '27', '112', '44', '53', '64', '107']], None),
#  ([[6743, 'Metal*Solo', '83', '101', '27', '53', '107', '107']], None),
#  ([[6744, 'C.O.B*****', '73', '72', '27', '98', '80', '56']], None),
#  ([[6745, 'WAH*BGN***', '27', '112', '44', '53', '64', '107']], None),
#  ([[6752, 'house*off*', '24', '2', '114', '21', '107', '107']], None),
#  ([[6763, 'WAH*BGN***', '27', '88', '30', '44', '53', '64']], None),
#  ([[6764, 'JP*Clean**', '23', '85', '41', '30', '54', '105']], None),
#  ([[6765, 'JP*Flanger', '23', '85', '46', '30', '54', '105']], None),
#  ([[6766, 'Acoustic**', '23', '85', '41', '60', '105', '107']], None),
#  ([[6767, 'BG*Drive**', '28', '73', '100', '31', '53', '105']], None),
#  ([[6776, '.Vultures', '23', '37', '27', '82', '30', '44'],
#    [6776, '.Flog', '23', '34', '85', '30', '36', '107'],
#    [6776, '.AC*life', '30', '44', '53', '64', '107', '107'],
#    [6776, '.Aural', '23', '33', '30', '107', '107', '107'],
#    [6776, '.Butter', '28', '95', '30', '57', '65', '107'],
#    [6776, '.Cement', '73', '53', '30', '65', '107', '107'],
#    [6776, '.Costra', '37', '28', '98', '30', '42', '107'],
#    [6776, '.Floats', '86', '30', '55', '53', '60', '107'],
#    [6776, '.Grind*hs', '71', '27', '101', '30', '49', '107'],
#    [6776, '.Hacking', '71', '29', '94', '30', '48', '56'],
#    [6776, '.Hairy', '29', '88', '30', '56', '63', '107'],
#    [6776, '.Leading', '27', '77', '30', '44', '53', '60'],
#    [6776, '.Mayflute', '23', '68', '29', '83', '61', '107'],
#    [6776, '.Mountain', '23', '28', '78', '30', '42', '61'],
#    [6776, '.Over*Me', '30', '49', '53', '107', '107', '107'],
#    [6776, '.Razors', '87', '30', '65', '107', '107', '107'],
#    [6776, '.Simprhyt', '77', '30', '107', '107', '107', '107'],
#    [6776, '.Snap', '38', '86', '30', '44', '53', '60'],
#    [6776, '.Thisway', '38', '30', '55', '57', '61', '107'],
#    [6776, '.Under*it', '23', '27', '74', '30', '51', '53'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, '80sWet', '27', '76', '30', '43', '56', '107'],
#    [6776, 'AcouSky', '27', '85', '30', '44', '53', '61'],
#    [6776, 'Alien*CL', '27', '85', '30', '35', '64', '107'],
#    [6776, 'Angra', '23', '28', '100', '30', '53', '107'],
#    [6776, 'Bossa', '27', '85', '30', '60', '107', '107'],
#    [6776, 'CharaDve', '23', '27', '94', '30', '107', '107'],
#    [6776, 'ClasEcho', '71', '27', '98', '30', '54', '61'],
#    [6776, 'AcouSky', '27', '85', '30', '44', '53', '61'],
#    [6776, 'ClassicD', '71', '27', '94', '30', '63', '107'],
#    [6776, 'Cmajor', '71', '27', '96', '52', '65', '107'],
#    [6776, 'CrArena', '27', '96', '30', '53', '64', '107'],
#    [6776, 'CryLead', '68', '27', '74', '30', '36', '107'],
#    [6776, 'Delta*B', '27', '93', '30', '63', '107', '107'],
#    [6776, 'Dynamic', '27', '95', '30', '55', '107', '107'],
#    [6776, 'EarlySlp', '27', '30', '45', '56', '65', '107'],
#    [6776, 'EZ*Lead', '71', '27', '99', '30', '54', '107'],
#    [6776, 'FilterLd', '27', '82', '30', '32', '53', '107'],
#    [6776, 'Face', '27', '95', '30', '107', '107', '107'],
#    [6776, 'FullOD', '28', '72', '30', '65', '107', '107'],
#    [6776, 'FusionCl', '23', '30', '44', '53', '107', '107'],
#    [6776, 'G*Shop', '71', '27', '98', '30', '61', '107'],
#    [6776, 'HeadHunt', '23', '34', '27', '30', '106', '62'],
#    [6776, 'Iommi', '27', '81', '30', '60', '107', '107'],
#    [6776, 'LeadCho', '27', '95', '30', '44', '53', '107'],
#    [6776, 'Low4th', '27', '72', '30', '52', '107', '107'],
#    [6776, 'MainRhyt', '71', '27', '99', '30', '53', '107'],
#    [6776, 'MoogWay', '33', '27', '93', '30', '53', '61'],
#    [6776, 'MultiTap', '23', '27', '30', '58', '107', '107'],
#    [6776, 'Muppets', '23', '27', '80', '30', '107', '107'],
#    [6776, 'NoAttack', '23', '26', '27', '30', '53', '107'],
#    [6776, 'OctUp', '27', '75', '30', '49', '60', '107'],
#    [6776, 'Octavia', '37', '27', '98', '30', '107', '107'],
#    [6776, 'OldJazz', '27', '30', '60', '107', '107', '107'],
#    [6776, 'PageArea', '27', '94', '30', '61', '107', '107'],
#    [6776, 'PhaseCL', '27', '30', '39', '64', '107', '107'],
#    [6776, 'PhaseCR', '27', '96', '30', '39', '61', '107'],
#    [6776, 'RingLead', '40', '27', '98', '30', '53', '62'],
#    [6776, 'Shadows', '71', '27', '99', '30', '45', '107'],
#    [6776, 'Sonhos', '23', '26', '49', '53', '63', '107'],
#    [6776, 'SprinTap', '23', '27', '30', '63', '107', '107'],
#    [6776, 'SprinVib', '27', '92', '30', '48', '54', '63'],
#    [6776, 'Start', '71', '27', '99', '30', '55', '60'],
#    [6776, 'Stern', '27', '30', '43', '54', '107', '107'],
#    [6776, 'Swell', '26', '28', '30', '48', '53', '62'],
#    [6776, 'Taj', '27', '49', '53', '107', '107', '107'],
#    [6776, 'TapClean', '23', '27', '30', '41', '60', '107'],
#    [6776, 'Tight*CL', '23', '27', '92', '30', '107', '107'],
#    [6776, 'Train', '38', '27', '72', '30', '62', '107'],
#    [6776, 'WavesRev', '27', '30', '44', '57', '60', '107'],
#    [6776, 'Zawi', '23', '27', '86', '35', '53', '60'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107'],
#    [6776, None, '107', '107', '107', '107', '107', '107']],
#   None),
#  ([[6787, 'TomMorello', '28', '70', '72', '95', '4', '53']], None),
#  ([[6788, 'Acustic***', '85', '43', '30', '7', '64', '27']], None),
#  ([[6806, 'BassGuitar', '37', '32', '86', '24', '44', '106']], None),
#  ([[6819, 'Rammstein1', '49', '27', '100', '30', '31', '44']], None),
#  ([[6824, 'JoesatTone', '67', '27', '99', '55', '55', '64']], None),
#  ([[6825, 'Shimmer***', '24', '2', '49', '105', '38', '64']], None),
#  ([[6826, 'Luv*n*H8*C', '107', '24', '108', '43', '107', '64']], None),
#  ([[6827, 'La*Luna***', '25', '68', '106', '88', '27', '16']], None),
#  ([[6833, 'hotelcalif', '115', '107', '107', '23', '107', '64']], None),
#  ([[6835, 'BitDelay', '56', '8', '41', '107', '107', '107']], None),
#  ([[6842, 'GroovyBass', '44', '106', '24', '37', '32', '86']], None),
#  ([[6846, 'rodolfo.*a', '27', '39', '30', '96', '44', '7']], None),
#  ([[6847, 'Sc00ps**', '27', '100', '30', '55', '53', '60'],
#    [6847, 'Cream***', '27', '75', '30', '42', '53', '63'],
#    [6847, 'Chalk***', '23', '27', '94', '30', '66', '53'],
#    [6847, 'Wowmen**', '23', '33', '92', '30', '43', '65'],
#    [6847, 'Synthish', '23', '37', '96', '30', '41', '64'],
#    [6847, 'Leading*', '23', '81', '30', '44', '53', '60'],
#    [6847, 'Grossnes', '40', '28', '72', '30', '49', '65'],
#    [6847, 'Angus***', '27', '96', '30', '53', '64', '107'],
#    [6847, 'Juice***', '28', '98', '30', '49', '107', '107'],
#    [6847, 'AC*house', '27', '85', '30', '49', '60', '107'],
#    [6847, 'EC*LEAD*', '71', '27', '94', '30', '63', '107'],
#    [6847, 'JB*Oct**', '37', '27', '98', '30', '54', '64'],
#    [6847, 'ZepStd**', '27', '94', '30', '61', '107', '107'],
#    [6847, 'JimiFuzz', '27', '78', '30', '49', '60', '107'],
#    [6847, 'JF*Riff*', '71', '27', '98', '30', '66', '61'],
#    [6847, 'JM*Lead*', '23', '27', '92', '30', '41', '61'],
#    [6847, 'DT*Slide', '71', '27', '94', '30', '63', '107'],
#    [6847, 'WildOzz*', '71', '27', '99', '30', '45', '107'],
#    [6847, 'Cowboy**', '71', '28', '84', '30', '69', '53'],
#    [6847, 'KC*Solo*', '27', '76', '30', '41', '56', '60'],
#    [6847, 'G-Shock', '71', '27', '99', '30', '53', '107'],
#    [6847, 'Every*BG', '23', '27', '94', '30', '63', '107'],
#    [6847, 'EVH1959', '71', '27', '98', '30', '62', '107'],
#    [6847, 'SL*Back', '27', '87', '30', '66', '53', '60'],
#    [6847, 'BS*Riff', '23', '27', '92', '30', '54', '107'],
#    [6847, 'BrianDrv', '71', '27', '91', '30', '53', '61'],
#    [6847, 'RitchStd', '71', '27', '98', '30', '61', '107'],
#    [6847, 'Carlos', '27', '95', '30', '64', '107', '107'],
#    [6847, 'PeteHW', '27', '96', '30', '61', '107', '107'],
#    [6847, 'BROTHER', '23', '27', '92', '30', '41', '60'],
#    [6847, 'JW*Talk', '68', '27', '78', '30', '36', '64'],
#    [6847, 'MB*Shock', '27', '75', '30', '56', '65', '107'],
#    [6847, 'KStone', '27', '93', '30', '63', '107', '107'],
#    [6847, 'ZZ', '23', '27', '82', '30', '62', '107'],
#    [6847, 'RR*Mtl', '23', '27', '80', '30', '44', '61'],
#    [6847, 'RSSitar', '34', '86', '30', '49', '53', '63'],
#    [6847, 'YngDrv', '71', '27', '99', '30', '54', '60'],
#    [6847, 'EricFuzz', '23', '71', '78', '30', '54', '60'],
#    [6847, 'Edge', '23', '27', '92', '30', '53', '60'],
#    [6847, 'JP*Drv', '23', '100', '30', '44', '53', '60'],
#    [6847, 'May', '27', '90', '30', '106', '54', '107'],
#    [6847, 'Woosh', '23', '27', '86', '35', '53', '107'],
#    [6847, 'Wet*Head', '23', '34', '30', '106', '53', '62'],
#    [6847, 'Wackjob', '23', '68', '27', '30', '39', '61'],
#    [6847, 'Dreamdrg', '23', '26', '27', '49', '53', '63'],
#    [6847, 'Milkyway', '27', '85', '30', '35', '53', '64'],
#    [6847, 'Oceans', '23', '27', '30', '44', '57', '60'],
#    [6847, 'Wreckles', '33', '100', '30', '44', '57', '60'],
#    [6847, 'Waves', '27', '86', '30', '44', '57', '58'],
#    [6847, 'Oceanflr', '23', '81', '30', '39', '57', '65'],
#    [6847, 'FdComp', '23', '27', '92', '30', '107', '107'],
#    [6847, 'FullVx', '27', '93', '30', '61', '107', '107'],
#    [6847, 'TexasMan', '27', '94', '30', '65', '107', '107'],
#    [6847, 'BgLead', '27', '95', '30', '54', '64', '107'],
#    [6847, 'HwCrunch', '27', '96', '30', '62', '107', '107'],
#    [6847, 'McCrunch', '27', '98', '30', '62', '107', '107'],
#    [6847, 'MdRhythm', '27', '99', '30', '65', '107', '107'],
#    [6847, 'PvRhythm', '27', '100', '30', '107', '107', '107'],
#    [6847, 'DzRhythm', '27', '101', '30', '107', '107', '107'],
#    [6847, 'BdRhythm', '27', '100', '30', '107', '107', '107'],
#    [6847, 'FatOd', '27', '72', '30', '62', '107', '107'],
#    [6847, 'TsDrive', '27', '73', '30', '107', '107', '107'],
#    [6847, 'GvDrive', '27', '74', '30', '107', '107', '107'],
#    [6847, 'dist+', '27', '75', '30', '107', '107', '107'],
#    [6847, 'DS1', '27', '76', '30', '53', '60', '107'],
#    [6847, 'RAT', '27', '77', '30', '56', '107', '107'],
#    [6847, 'FatFace', '27', '78', '30', '62', '107', '107'],
#    [6847, 'MuffDrv', '27', '79', '30', '61', '107', '107'],
#    [6847, 'M*World', '27', '80', '30', '54', '107', '107'],
#    [6847, 'HOT*DRV', '27', '81', '30', '60', '107', '107'],
#    [6847, 'Z*CLEAN', '23', '27', '86', '30', '41', '56'],
#    [6847, 'Z*WILD', '27', '82', '30', '107', '107', '107'],
#    [6847, 'Z*MP1', '27', '87', '30', '107', '107', '107'],
#    [6847, 'Z*BOTTOM', '27', '88', '30', '107', '107', '107'],
#    [6847, 'Z*DREAM', '27', '89', '30', '63', '107', '107'],
#    [6847, 'Z*SCREAM', '27', '90', '30', '61', '107', '107'],
#    [6847, 'Z*NEOS', '27', '91', '30', '61', '107', '107'],
#    [6847, 'LEAD', '27', '83', '30', '54', '60', '107'],
#    [6847, 'EXT*DS', '28', '84', '30', '107', '107', '107'],
#    [6847, 'ACOSIM', '27', '85', '30', '61', '107', '107'],
#    [6847, 'M*Comp', '23', '27', '107', '107', '107', '107'],
#    [6847, 'Auto*Wah', '33', '27', '30', '107', '107', '107'],
#    [6847, 'Reso', '34', '27', '107', '107', '107', '107'],
#    [6847, 'Tremolo', '38', '27', '107', '107', '107', '107'],
#    [6847, 'PDLWah', '68', '27', '107', '107', '107', '107'],
#    [6847, 'Octave', '37', '27', '107', '107', '107', '107'],
#    [6847, 'Vin*CE', '27', '43', '107', '107', '107', '107'],
#    [6847, 'Phaser', '27', '39', '107', '107', '107', '107'],
#    [6847, 'Flanger', '27', '106', '107', '107', '107', '107'],
#    [6847, 'Vibrato', '27', '48', '107', '107', '107', '107'],
#    [6847, 'Cry', '27', '93', '36', '107', '107', '107'],
#    [6847, 'H.P.S', '27', '72', '52', '107', '107', '107'],
#    [6847, 'PDLPitch', '27', '82', '69', '53', '107', '107'],
#    [6847, 'TapeEcho', '27', '98', '54', '107', '107', '107'],
#    [6847, 'PP*Delay', '27', '30', '53', '107', '107', '107'],
#    [6847, 'Reverse', '27', '57', '107', '107', '107', '107'],
#    [6847, 'Hall', '27', '60', '107', '107', '107', '107'],
#    [6847, 'Spring', '27', '92', '63', '107', '107', '107'],
#    [6847, 'EarlyRef', '27', '98', '65', '107', '107', '107'],
#    [6847, 'MultiTap', '27', '58', '107', '107', '107', '107']],
#   None),
#  ([[6879, 'berlin****', '107', '27', '24', '63', '66', '111']], None),
#  ([[6903, 'WAH*BGN***', '68', '110', '27', '44', '7', '105'],
#    [6903, 'TREM*FD***', '71', '38', '92', '54', '107', '107'],
#    [6903, 'DZ*Bend***', '28', '70', '101', '65', '107', '107'],
#    [6903, 'MoveJet***', '27', '46', '97', '60', '107', '107'],
#    [6903, 'FunkyWah**', '67', '19', '27', '92', '105', '107'],
#    [6903, 'MS*Echo***', '27', '73', '98', '30', '54', '64'],
#    [6903, 'MultiMod**', '27', '92', '10', '44', '7', '107'],
#    [6903, 'ShuffleAT*', '27', '3', '113', '60', '107', '107'],
#    [6903, 'DriveA-Wah', '27', '33', '114', '63', '107', '107'],
#    [6903, 'Taste-AC**', '27', '25', '85', '43', '66', '60'],
#    [6903, 'GoodFuzz**', '78', '98', '63', '27', '107', '107'],
#    [6903, 'Jazz******', '25', '41', '92', '53', '107', '107'],
#    [6903, 'Fripper***', '79', '27', '96', '57', '60', '107'],
#    [6903, 'Horn******', '27', '102', '31', '66', '64', '107'],
#    [6903, 'Clean*FLNG', '28', '23', '46', '92', '63', '107'],
#    [6903, 'DST&VIBRO*', '28', '68', '75', '104', '60', '107'],
#    [6903, 'Fast*Filt*', '27', '23', '0', '92', '5', '62'],
#    [6903, 'CRY&BLUES*', '68', '24', '109', '66', '107', '107'],
#    [6903, 'BoostCity*', '67', '71', '108', '27', '62', '107'],
#    [6903, 'Heaven****', '26', '12', '92', '44', '7', '60'],
#    [6903, 'StereoFunk', '23', '33', '30', '66', '107', '107'],
#    [6903, 'Tele*ClnRW', '23', '30', '44', '107', '107', '107'],
#    [6903, '410BlsSolo', '94', '23', '65', '59', '107', '107'],
#    [6903, 'Str*Cln*LD', '23', '31', '43', '18', '107', '107'],
#    [6903, 'Trem*Clean', '23', '30', '38', '60', '107', '107'],
#    [6903, 'Elec*Rhyth', '24', '95', '65', '107', '107', '107'],
#    [6903, 'Washed*Out', '114', '16', '23', '107', '107', '107'],
#    [6903, 'BigFatFlng', '24', '21', '109', '107', '107', '107'],
#    [6903, 'Robo*Funk*', '25', '13', '31', '107', '107', '107'],
#    [6903, 'Fool*Frnds', '23', '30', '85', '60', '107', '107'],
#    [6903, 'MatchVibe*', '72', '103', '1', '56', '66', '107'],
#    [6903, 'Revolving*', '73', '113', '55', '61', '107', '107'],
#    [6903, 'Livid*****', '23', '44', '56', '18', '107', '107'],
#    [6903, 'ValleyRock', '47', '73', '99', '53', '60', '107'],
#    [6903, 'IndieDrive', '67', '71', '97', '53', '4', '107'],
#    [6903, 'MetallicCh', '27', '67', '100', '17', '107', '107'],
#    [6903, 'Progressng', '70', '72', '95', '4', '53', '107'],
#    [6903, 'Enfermo***', '28', '71', '110', '64', '107', '107'],
#    [6903, '7*mirrors*', '24', '26', '92', '44', '7', '58'],
#    [6903, 'HolyShift*', '110', '52', '5', '60', '107', '107'],
#    [6903, 'Honeydrip*', '25', '73', '54', '107', '107', '107'],
#    [6903, "It's*Alive", '11', '74', '54', '34', '107', '107'],
#    [6903, 'Tropicana*', '30', '74', '97', '27', '63', '107'],
#    [6903, 'Thrash*Em*', '73', '98', '27', '61', '107', '107'],
#    [6903, 'Zipper****', '79', '111', '27', '66', '107', '107'],
#    [6903, 'Solottery*', '25', '71', '56', '95', '107', '107'],
#    [6903, 'Creeper***', '17', '26', '89', '105', '107', '107'],
#    [6903, 'Heavy*D***', '88', '100', '27', '107', '107', '107'],
#    [6903, 'Classic***', '81', '92', '63', '107', '107', '107'],
#    [6903, 'Wood******', '74', '36', '25', '27', '111', '107'],
#    [6903, 'XtremeWah*', '33', '84', '5', '25', '28', '107'],
#    [6903, 'HeavyMedal', '80', '30', '28', '107', '107', '107'],
#    [6903, 'MetaSynCor', '80', '30', '11', '41', '53', '28'],
#    [6903, 'StackedUp*', '96', '53', '64', '46', '24', '28'],
#    [6903, 'AngelFaze*', '85', '21', '5', '64', '107', '107'],
#    [6903, 'MrGovenor*', '74', '31', '53', '60', '28', '107'],
#    [6903, 'PitchedOut', '87', '31', '49', '52', '49', '28'],
#    [6903, 'Open*Wah!*', '36', '24', '30', '18', '107', '107'],
#    [6903, 'CrunchCore', '77', '30', '44', '28', '107', '107'],
#    [6903, 'DreamScape', '0', '6', '24', '107', '107', '107'],
#    [6903, 'FD*COMBO**', '67', '24', '63', '92', '61', '107'],
#    [6903, 'DELUXE-R**', '81', '111', '63', '56', '61', '107'],
#    [6903, 'FD*VIBRO**', '38', '104', '63', '66', '107', '107'],
#    [6903, 'US*BLUES**', '94', '65', '54', '105', '107', '107'],
#    [6903, 'VX*COMBO**', '93', '65', '45', '60', '107', '107'],
#    [6903, 'VX*JMI****', '71', '116', '27', '65', '61', '7'],
#    [6903, 'BG*CRUNCH*', '95', '27', '65', '56', '60', '107'],
#    [6903, 'MATCH30***', '67', '103', '27', '66', '107', '107'],
#    [6903, 'CAR*DRIVE*', '68', '114', '27', '63', '66', '107'],
#    [6903, 'TW*ROCK***', '102', '27', '65', '4', '107', '107'],
#    [6903, 'TONE*CITY*', '108', '27', '46', '62', '107', '107'],
#    [6903, 'HW*STACK**', '96', '27', '65', '66', '107', '107'],
#    [6903, 'TANGERINE*', '39', '97', '27', '65', '61', '107'],
#    [6903, 'B-BREAKER*', '109', '27', '65', '62', '107', '107'],
#    [6903, 'MS*CRUNCH*', '73', '98', '27', '66', '53', '60'],
#    [6903, 'MS1959****', '1', '115', '27', '53', '61', '107'],
#    [6903, 'MS*DRIVE**', '23', '99', '27', '66', '60', '107'],
#    [6903, 'BGN*DRIVE*', '110', '27', '44', '7', '105', '107'],
#    [6903, 'BG*DRIVE**', '70', '100', '27', '65', '107', '107'],
#    [6903, 'DZ*DRIVE**', '101', '27', '62', '107', '107', '107'],
#    [6903, 'ALIEN*****', '112', '27', '5', '107', '107', '107'],
#    [6903, 'REVO-1****', '68', '28', '113', '66', '107', '107'],
#    [6903, 'JB*Crunch*', '27', '109', '30', '64', '107', '107'],
#    [6903, 'BrianDL***', '27', '31', '93', '7', '107', '107'],
#    [6903, 'Smooth****', '27', '73', '98', '30', '53', '64'],
#    [6903, 'Hendrix***', '67', '78', '1', '98', '107', '107'],
#    [6903, 'MetalKirk*', '68', '100', '44', '60', '107', '107'],
#    [6903, 'U2....****', '24', '43', '93', '7', '107', '107'],
#    [6903, 'E.V.H*****', '29', '110', '105', '107', '107', '107'],
#    [6903, 'Beatle*AC*', '28', '93', '66', '60', '107', '107'],
#    [6903, 'J.Page****', '68', '71', '98', '60', '107', '107'],
#    [6903, 'Layla...**', '74', '109', '61', '107', '107', '107'],
#    [6903, 'Mr.Moore**', '27', '74', '98', '53', '63', '107'],
#    [6903, 'M.S-Wah***', '27', '68', '98', '61', '107', '107'],
#    [6903, 'JazzFusion', '27', '94', '45', '56', '107', '107'],
#    [6903, 'Step*Chord', '28', '35', '100', '3', '65', '107'],
#    [6903, 'FilterCLN*', '27', '23', '0', '92', '55', '60'],
#    [6903, 'Theremin**', '11', '92', '53', '64', '107', '107'],
#    [6903, 'Atom******', '27', '92', '6', '44', '60', '107'],
#    [6903, 'DreamSeq**', '89', '12', '7', '107', '107', '107']],
#   None),
#  ([[6929, 'HVDrv*****', '27', '80', '100', '30', '18', '107']], None),
#  ([[6930, 'HVDrv*****', '27', '80', '100', '30', '18', '107']], None),
#  ([[6931, 'HarmoAmoll', '113', '41', '70', '107', '107', '107']], None),
#  ([[6932, 'Over+Clean', '86', '94', '31', '107', '53', '105']], None),
#  ([[6933, 'Clean*Vibe', '63', '116', '1', '107', '107', '107']], None),
#  ([[6934, 'Clean*****', '85', '66', '41', '56', '107', '107']], None),
#  ([[6935, 'Przester3*', '24', '73', '71', '27', '113', '30']], None),
#  ([[6955, 'TomMorello', '28', '70', '72', '95', '30', '53']], None),
#  ([[6956, 'BeYourSelf', '97', '60', '67', '72', '41', '105']], None),
#  ([[6957, 'FadeToBlak', '27', '68', '72', '95', '62', '30']], None),
#  ([[6958, 'Acust-Fade', '27', '25', '85', '43', '30', '60']], None),
#  ([[6959, 'LikeAStone', '30', '86', '38', '72', '107', '107']], None),
#  ([[6960, 'Trem-Like*', '71', '38', '92', '54', '107', '107']], None),
#  ([[6961, '**Whammy**', '70', '100', '27', '65', '46', '30']], None),
#  ([[6971, 'SinceSoloG', '23', '71', '27', '95', '30', '18']], None),
#  ([[6972, 'SinceSoloG', '23', '71', '27', '95', '30', '18']], None),
#  ([[6974, 'AintTalkin', '27', '23', '75', '110', '46', '105']], None),
#  ([[6984, 'ImgsWrdsRh', '27', '71', '22', '103', '30', '31']], None),
#  ([[6985, 'ImgsWrdsLd', '27', '22', '103', '30', '31', '18']], None),
#  ([[6986, 'JpOldClean', '23', '85', '43', '30', '64', '66']], None),
#  ([[6987, 'PJBETTERMA', '103', '71', '107', '107', '107', '107']], None),
#  ([[6988, 'HeavensDoo', '74', '115', '60', '107', '107', '107']], None),
#  ([[6993, 'Rumble****', '72', '115', '38', '107', '107', '107']], None),
#  ([[7000, 'IOMMI*****', '27', '72', '30', '60', '96', '107']], None),
#  ([[7001, 'Blink-182', '28', '80', '30', '92', '107', '107']], None),
#  ([[7002, 'Blink-182*', '28', '80', '30', '92', '107', '107']], None),
#  ([[7005, 'Tunnel****', '23', '30', '92', '64', '107', '107']], None),
#  ([[7007, 'AcDc******', '27', '25', '73', '98', '30', '61']], None),
#  ([[7008, 'sultanlive', '24', '30', '92', '64', '107', '107']], None),
#  ([[7009, 'SpaceEcho', '33', '84', '5', '25', '28', '107']], None),
#  ([[7021, "Dom's*Set*", '27', '76', '71', '11', '63', '92']], None),
#  ([[7025, 'Djenty****', '27', '112', '30', '107', '107', '107']], None),
#  ([[7029, 'Esandman**', '85', '93', '31', '60', '44', '53']], None),
#  ([[7035, 'E*Tun*to*D', '69', '69', '69', '69', '113', '107']], None),
#  ([[7042, 'Vivid*Cln*', '27', '85', '30', '16', '66', '107']], None),
#  ([[7050, 'punked****', '28', '73', '79', '92', '107', '107']], None),
#  ([[7051, 'ACDC******', '27', '95', '60', '107', '107', '107']], None),
#  ([[7061, 'ratmdis+', '28', '23', '71', '75', '37', '92']], None),
#  ([[7062, 'ratmdis1**', '28', '23', '71', '76', '37', '92']], None),
#  ([], (7074, Exception('Unknown format: rar'))),
#  ([[7082, 'Twn*Reverb', '107', '92', '107', '107', '107', '107'],
#    [7082, 'Dlx*Reverb', '107', '111', '107', '107', '107', '107'],
#    [7082, 'Vibroverb*', '107', '104', '107', '107', '107', '107'],
#    [7082, 'TwdBassman', '107', '94', '107', '107', '107', '107'],
#    [7082, 'VoxCombo**', '107', '93', '107', '107', '107', '107'],
#    [7082, 'Vox*JMI***', '107', '116', '107', '107', '107', '107'],
#    [7082, 'MS62BlsBrk', '107', '109', '107', '107', '107', '107'],
#    [7082, 'MS*1959***', '107', '98', '107', '107', '107', '107'],
#    [7082, 'MS59Plexi*', '107', '115', '107', '107', '107', '107'],
#    [7082, 'HiWatt100*', '107', '96', '107', '107', '107', '107'],
#    [7082, 'MesaDlRect', '107', '100', '107', '107', '107', '107'],
#    [7082, 'KrankRev1+', '107', '113', '107', '107', '107', '107'],
#    [7082, 'EnglInvadr', '107', '112', '107', '107', '107', '107'],
#    [7082, 'MS*JCM2000', '107', '99', '107', '107', '107', '107'],
#    [7082, 'DiezelHerb', '107', '101', '107', '107', '107', '107'],
#    [7082, 'SndCty50+2', '107', '108', '107', '107', '107', '107'],
#    [7082, 'OrgGrap120', '107', '97', '107', '107', '107', '107'],
#    [7082, '2RckEmer50', '107', '102', '107', '107', '107', '107'],
#    [7082, 'MesaMKIII*', '107', '95', '107', '107', '107', '107'],
#    [7082, 'BogEcstasy', '107', '110', '107', '107', '107', '107'],
#    [7082, 'CarrMercry', '107', '114', '107', '107', '107', '107'],
#    [7082, 'MatchDC-30', '107', '103', '107', '107', '107', '107'],
#    [7082, 'MatchHotBx', '107', '81', '107', '107', '107', '107'],
#    [7082, 'Z*Clean', '107', '86', '107', '107', '107', '107'],
#    [7082, 'Z*AcousSim', '107', '85', '107', '107', '107', '107'],
#    [7082, 'Z*MP1', '107', '87', '107', '107', '107', '107'],
#    [7082, 'Z*Bottom', '107', '88', '107', '107', '107', '107'],
#    [7082, 'Z*Dream', '107', '89', '107', '107', '107', '107'],
#    [7082, 'Z*Scream', '107', '90', '107', '107', '107', '107'],
#    [7082, 'Z*Neos', '107', '91', '107', '107', '107', '107'],
#    [7082, 'Z*Wild', '107', '82', '107', '107', '107', '107'],
#    [7082, 'Z*Lead', '107', '83', '107', '107', '107', '107'],
#    [7082, 'Z*XtrmDist', '107', '84', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107'],
#    [7082, None, '107', '107', '107', '107', '107', '107']],
#   None),
#  ([[7083, 'TW*Crunch*', '73', '106', '62'],
#    [7083, 'Cut*Edge', '24', '96', '17'],
#    [7083, 'VX*DRIVE**', '73', '97', '62'],
#    [7083, 'JB*Talk***', '37', '102', '65'],
#    [7083, 'MS*FULLUP*', '102', '55', '61'],
#    [7083, 'Strings', '27', '45', '8'],
#    [7083, 'Elegant', '105', '8', '8'],
#    [7083, 'Super*Dry*', '29', '72', '105'],
#    [7083, 'HW*STACK', '100', '67', '62'],
#    [7083, 'Horizons**', '86', '42', '19'],
#    [7083, 'Angra*****', '104', '28', '54'],
#    [7083, 'Percussive', '20', '96', '64'],
# ...
#    [10822, 'Steve*Vai*', '27', '112', '30', '66', '53', '107'],
#    [10822, 'Heavy*Tone', '28', '73', '30', '101', '27', '107'],
#    [10822, 'Syn*Gates*', '107', '28', '23', '73', '101', '60'],
#    [10822, 'TeenSpirit', '77', '95', '45', '27', '62', '66'],
#    [10822, 'METAL*2***', '27', '73', '113', '107', '107', '107'],
#    [10822, 'Gilmour***', '28', '78', '24', '60', '116', '7'],
#    [10822, 'YJM**', '23', '71', '27', '115', '18', '107'],
#    [10822, 'War*Arch#1', '24', '73', '113', '27', '30', '30'],
#    [10822, 'War*Arch#2', '24', '73', '99', '27', '30', '30'],
#    [10822, 'Wylde*****', '72', '99', '41', '107', '107', '107'],
#    [10822, 'Vulgar*D', '107', '101', '62', '31', '44', '27'],
#    [10822, 'Chorus*SOL', '27', '73', '99', '52', '16', '64'],
#    [10822, 'SquareB', '23', '71', '27', '92', '37', '44'],
#    [10822, 'SmingAlien', '107', '73', '112', '27', '60', '107'],
#    [10822, 'Satriani**', '28', '68', '73', '99', '59', '64'],
#    [10822, 'satch*1', '27', '32', '73', '56', '115', '105'],
#    [10822, 'ScMoore~**', '27', '56', '94', '66', '107', '107'],
#    [10822, 'Slash*****', '28', '68', '23', '73', '99', '59'],
#    [10822, 'RUST*DAVE*', '27', '73', '110', '30', '61', '107'],
#    [10822, 'PinkSintro', '93', '24', '34', '26', '6', '18'],
#    [10822, '90*metal**', '100', '31', '30', '44', '18', '27'],
#    [10822, 'overdrive2', '106', '100', '27', '65', '59', '64'],
#    [10822, 'OD*HW*****', '27', '23', '71', '72', '76', '96'],
#    [10822, 'OldSmith**', '23', '98', '23', '107', '107', '107'],
#    [10822, 'plexi*dly*', '73', '98', '54', '107', '107', '107'],
#    [10822, 'PiB-Fuzz**', '28', '19', '79', '101', '105', '54'],
#    [10822, 'PrettyWman', '27', '41', '98', '53', '66', '105'],
#    [10822, 'Red*Hot*Ch', '23', '60', '27', '83', '73', '92'],
#    [10822, 'Refuzzverb', '27', '78', '96', '57', '66', '107'],
#    [10822, 'Tool******', '27', '74', '84', '30', '106', '38'],
#    [10822, 'Sevenfold*', '73', '100', '52', '107', '107', '107'],
#    [10822, 'Sex*Pistol', '27', '92', '107', '107', '107', '107'],
#    [10822, 'Psycho****', '28', '70', '79', '39', '98', '60'],
#    [10822, 'Nickelback', '99', '45', '61', '28', '107', '107'],
#    [10822, 'AcouORG5**', '26', '2', '21', '85', '7', '105'],
#    [10822, 'mrjohnson*', '27', '23', '73', '115', '56', '18'],
#    [10822, 'mouth*war*', '27', '101', '30', '107', '107', '107'],
#    [10822, 'Mr.Angus', '27', '31', '99', '42', '62', '107'],
#    [10822, 'MS*Crunch*', '29', '83', '98', '53', '107', '107'],
#    [10822, 'BeachBBVI#', '27', '38', '63', '104', '24', '62'],
#    [10822, 'BBKing~***', '107', '27', '111', '60', '107', '107'],
#    [10822, 'Battery***', '27', '72', '99', '30', '60', '44'],
#    [10822, 'C.O.B*****', '73', '72', '27', '98', '80', '56'],
#    [10822, 'California', '27', '71', '84', '30', '30', '65'],
#    [10822, 'Ch*Grove**', '74', '18', '31', '28', '30', '107'],
#    [10822, 'CLEAN*Moj*', '27', '92', '28', '32', '66', '53'],
#    [10822, 'CMNA*DIST2', '73', '29', '80', '28', '30', '64'],
#    [10822, 'Cocain', '73', '104', '27', '107', '107', '107'],
#    [10822, 'come*asyou', '45', '44', '43', '41', '31', '24'],
#    [10822, 'Delay*Stup', '85', '21', '107', '64', '7', '16'],
#    [10822, 'DavidGilmr', '24', '47', '41', '53', '107', '107'],
#    [10822, 'LEAD*ALIEN', '25', '83', '112', '31', '45', '53'],
#    [10822, 'LEAD*FBCOM', '25', '83', '92', '31', '45', '53'],
#    [10822, 'LEAD*SHIM*', '89', '26', '52', '5', '55', '18']],
#   None),
#  ([[10849, '**********', '107', '107', '107', '107', '107', '84'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107'],
#    [10849, None, '107', '107', '107', '107', '107', '107']],
#   None),
#  ([[10850, 'ALIEN*sol*', '27', '73', '112', '43', '7', '66'],
#    [10850, 'Darkness**', '79', '37', '63', '107', '107', '107'],
#    [10850, 'Psionic***', '73', '12', '1', '88', '107', '107'],
#    [10850, 'Juicy', '89', '34', '29', '61', '107', '107'],
#    [10850, 'Orbital***', '72', '17', '38', '26', '107', '107'],
#    [10850, 'Space*Lead', '22', '5', '107', '107', '107', '107'],
#    [10850, 'Blue*Glass', '86', '43', '63', '56', '107', '107'],
#    [10850, 'Broken****', '75', '8', '107', '107', '107', '107'],
#    [10850, 'The*Nerve*', '90', '45', '40', '25', '66', '107'],
#    [10850, "It's*Alive", '11', '74', '54', '34', '107', '107'],
#    [10850, 'Rear*View*', '73', '3', '57', '107', '107', '107'],
#    [10850, 'Tropicana*', '30', '74', '97', '27', '63', '107'],
#    [10850, 'Lush*Drunk', '103', '61', '0', '54', '107', '107'],
#    [10850, 'Thrash*Em*', '73', '98', '27', '61', '107', '107'],
#    [10850, 'Anger*Sync', '101', '27', '3', '107', '107', '107'],
#    [10850, 'Flunky****', '25', '46', '0', '93', '63', '107'],
#    [10850, 'Zipper****', '79', '111', '27', '66', '107', '107'],
#    [10850, 'Running***', '25', '39', '53', '96', '61', '107'],
#    [10850, 'Solottery*', '25', '71', '56', '95', '107', '107'],
#    [10850, 'Creeper***', '17', '26', '89', '105', '107', '107'],
#    [10850, 'Mrs.*Clean', '86', '92', '17', '54', '107', '107'],
#    [10850, 'Lil*Mac***', '91', '92', '27', '61', '107', '107'],
#    [10850, "Burnin'***", '84', '102', '27', '63', '107', '107'],
#    [10850, 'Warmth****', '86', '103', '63', '107', '107', '107'],
#    [10850, 'The*Point*', '32', '31', '82', '93', '27', '107'],
#    [10850, 'Fatso*****', '37', '78', '25', '29', '97', '66'],
#    [10850, 'The*Brat**', '81', '27', '8', '111', '54', '107'],
#    [10850, 'Weeds*****', '23', '89', '27', '95', '65', '107'],
#    [10850, 'Fat*Cat***', '76', '77', '27', '114', '59', '107'],
#    [10850, 'CrossEye**', '14', '40', '11', '71', '114', '27'],
#    [10850, 'Heavy*D***', '88', '100', '27', '71', '107', '107'],
#    [10850, 'Classic***', '81', '92', '63', '107', '107', '107'],
#    [10850, 'Dreams****', '21', '86', '92', '24', '5', '107'],
#    [10850, 'Madness***', '12', '0', '25', '87', '27', '45'],
#    [10850, 'Proverbs**', '91', '41', '61', '103', '107', '107'],
#    [10850, 'Chopper***', '82', '38', '102', '27', '107', '107'],
#    [10850, 'Wood******', '74', '36', '25', '27', '111', '107'],
#    [10850, 'AutoDrive*', '33', '76', '24', '60', '41', '107'],
#    [10850, 'AutoScream', '33', '75', '62', '24', '107', '107'],
#    [10850, 'XtremeWah*', '33', '84', '5', '25', '28', '107'],
#    [10850, 'HeavyMedal', '80', '30', '107', '28', '107', '107'],
#    [10850, 'MetaSynCor', '80', '30', '11', '41', '53', '28'],
#    [10850, 'WashedAway', '84', '41', '51', '21', '28', '64'],
#    [10850, 'TastyTang*', '97', '24', '53', '28', '107', '107'],
#    [10850, 'StackedUp*', '96', '53', '64', '46', '24', '28'],
#    [10850, 'HighWatt**', '96', '31', '28', '107', '107', '107'],
#    [10850, 'AngelSky**', '85', '16', '105', '107', '107', '107'],
#    [10850, 'AngelFaze*', '85', '21', '5', '64', '107', '107'],
#    [10850, 'Eds*Thang*', '85', '18', '24', '107', '107', '107'],
#    [10850, 'CountryDrt', '103', '24', '53', '107', '107', '107'],
#    [10850, 'KernelLee*', '103', '53', '24', '60', '28', '107'],
#    [10850, 'MrGovenor*', '74', '31', '53', '60', '28', '107'],
#    [10850, 'Echo2Marsh', '74', '31', '58', '44', '54', '28'],
#    [10850, 'PitchedOut', '87', '31', '49', '52', '49', '28'],
#    [10850, 'Trevor`***', '82', '31', '63', '52', '52', '28'],
#    [10850, 'LEAD*SHIM*', '89', '26', '52', '5', '55', '18'],
#    [10850, 'TomMorello', '28', '70', '72', '95', '30', '53'],
#    [10850, '**Whammy**', '70', '100', '27', '65', '46', '30'],
#    [10850, 'CaptCrunch', '77', '30', '28', '107', '107', '107'],
#    [10850, 'CrunchFaze', '77', '30', '19', '28', '107', '107'],
#    [10850, 'CrunchCore', '77', '30', '44', '28', '107', '107'],
#    [10850, 'CrunchEcho', '77', '30', '44', '53', '53', '53'],
#    [10850, 'ChunkFlang', '77', '30', '106', '46', '106', '28'],
#    [10850, 'FredFiltas', '92', '35', '12', '13', '24', '107'],
#    [10850, 'St-e-v-Ray', '71', '111', '24', '28', '107', '107'],
#    [10850, 'SRVeeTrem*', '71', '111', '24', '38', '38', '48'],
#    [10850, 'StevieWah*', '71', '111', '24', '36', '36', '36'],
#    [10850, 'BigBottom*', '110', '30', '37', '28', '107', '107'],
#    [10850, 'DelayDream', '92', '31', '7', '24', '107', '107'],
#    [10850, 'ZBottmWahs', '67', '88', '28', '107', '107', '107'],
#    [10850, 'ScreamnWah', '68', '84', '28', '107', '107', '107'],
#    [10850, 'WoundedBee', '103', '30', '53', '28', '107', '107'],
#    [10850, 'YouGotMe**', '77', '54', '60', '106', '28', '107'],
#    [10850, 'DreamScape', '0', '6', '24', '107', '107', '107'],
#    [10850, 'BluesyFaze', '109', '10', '19', '14', '28', '107'],
#    [10850, 'VxFaze****', '93', '4', '30', '28', '107', '107'],
#    [10850, 'TremGun***', '27', '112', '3', '64', '107', '107'],
#    [10850, 'FMD*******', '34', '92', '30', '55', '44', '7'],
#    [10850, 'BrokenRD**', '27', '8', '101', '63', '107', '107'],
#    [10850, 'PAD*******', '26', '49', '104', '44', '7', '64'],
#    [10850, 'Ringie!!!*', '74', '40', '112', '27', '53', '107'],
#    [10850, '3rdWorld**', '102', '52', '5', '105', '107', '107'],
#    [10850, 'FilterCLN', '27', '23', '0', '92', '55', '60'],
#    [10850, 'Radio*****', '28', '72', '30', '31', '8', '61'],
#    [10850, 'Step-UP***', '27', '24', '12', '93', '6', '65'],
#    [10850, 'PDLFL*****', '27', '46', '100', '54', '107', '107'],
#    [10850, 'PedalRing*', '27', '40', '100', '44', '56', '107'],
#    [10850, 'Atom******', '27', '92', '6', '44', '60', '107'],
#    [10850, 'FunkBass!*', '23', '36', '71', '96', '11', '107'],
#    [10850, 'Theremin', '11', '92', '53', '64', '107', '107'],
#    [10850, 'Devil*+++*', '70', '71', '36', '40', '112', '53'],
#    [10850, 'TaurusBS', '11', '31', '49', '107', '107', '107'],
#    [10850, 'Cascading', '25', '92', '45', '6', '64', '107'],
#    [10850, 'PlayWiRazr', '76', '3', '40', '107', '107', '107'],
#    [10850, 'be*alarmed', '27', '25', '53', '33', '0', '50'],
#    [10850, 'Step*Chord', '28', '35', '100', '3', '65', '107'],
#    [10850, 'DreamSeq**', '89', '12', '53', '107', '107', '107'],
#    [10850, '0LA*Beybe*', '24', '73', '71', '30', '27', '113'],
#    [10850, 'BASE*13', '27', '73', '110', '30', '107', '107'],
#    [10850, 'Diezel****', '27', '73', '39', '101', '53', '30']],
#   None),
#  ([[10870, 'David*****', '27', '78', '39', '43', '96', '18']], None),
#  ([[10871, 'Pink', '27', '79', '25', '30', '45', '64']], None),
#  ([[10872, 'Bass******', '30', '37', '94', '24', '107', '107']], None)]

# %%
from functools import reduce

data, errors = zip(*result)

data = reduce(lambda a, b: a+b, data)
errors = list(filter(lambda e: e != None, errors))

errors = [(index, str(error)) for index, error in errors]

# %%
labels = ['id', 'name', 'plugin1', 'plugin2', 'plugin3', 'plugin4', 'plugin5', 'plugin6']

d = pd.DataFrame.from_records(data, columns=labels, index='id')
#d = d.drop_duplicates()
d = d.sort_values('name')

d.head(10)
# Out:
#              name plugin1 plugin2 plugin3 plugin4 plugin5 plugin6
# id
# 9467     !!*Cuda'      23      27      73     109     106      61
# 8913   '70s*V.H**      39      30     100      60     107     107
# 7313   '70s*V.H**      39      30     100      60     107     107
# 9471   '70s*V.H**      39      30     100      60     107     107
# 7313   '90s*V.H**      23      99      31      42      53      60
# 9672   *!!*Wanted      23      27      85      49      60     107
# 9467   *!!*Wanted      23      27      85      49      60     107
# 10623  **********     107     107     107     107     107     107
# 10623  **********     107     107     107     107     107     107
# 10623  **********     107     107     107     107     107     107

# %%
import operator
import functools

def columns_same_effect(effect):
    columns = ['plugin{}'.format(i) for i in range(1, 7)]
    return reduce(operator.and_, [d[column] == str(effect) for column in columns])

# Replace all NaN to 107 - None
d = d.fillna('107')
print(len(d), 'patches')
# Out:
# 4408 patches

# %%
# Remove effects with all effects equals
for i in range(117):
    d = d[~columns_same_effect(i)]

print(len(d), 'unique patches - disconsidering parameters')
# Out:
# 3121 unique patches - disconsidering parameters

# %%
d.to_csv('data/pedalboard-plugin.csv')
d.head(10)
# Out:
#              name plugin1 plugin2 plugin3 plugin4 plugin5 plugin6
# id
# 9467     !!*Cuda'      23      27      73     109     106      61
# 8913   '70s*V.H**      39      30     100      60     107     107
# 7313   '70s*V.H**      39      30     100      60     107     107
# 9471   '70s*V.H**      39      30     100      60     107     107
# 7313   '90s*V.H**      23      99      31      42      53      60
# 9672   *!!*Wanted      23      27      85      49      60     107
# 9467   *!!*Wanted      23      27      85      49      60     107
# 9588   **********     107     107     107      27     107      31
# 10849  **********     107     107     107     107     107      84
# 9467   ****EMG*81      23      27      72     101     105     107

# %%
e = pd.DataFrame.from_records(errors, columns=['id', 'error'], index='id')
e.to_csv('data/pedalboard-plugin-error.csv')
e
# Out:
#                                     error
# id
# 6361                'content-disposition'
# 7074                  Unknown format: rar
# 7975                  Unknown format: jpg
# 7976                  Unknown format: jpg
# 8313                  Unknown format: rar
# 8447                  Unknown format: g5p
# 9416                  Unknown format: g5a
# 9592   no element found: line 1, column 0
# 9876                  Unknown format: rar
# 10190                 Unknown format: xml
# 10640                           'Module5'
# 10678                Unknown format: zptc
# 10774                Unknown format: zptc
# 10775                Unknown format: zptc
# 10776                Unknown format: zptc
# 10777                Unknown format: zptc
# 10778                Unknown format: zptc
# 10779                Unknown format: zptc
